# %% [markdown]
# <a href="https://colab.research.google.com/github/CynH3x/iris-flower-classification/blob/main/Iris_Flower_Classification_using_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
